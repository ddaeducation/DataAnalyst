# %% [markdown]
# <a href="https://colab.research.google.com/github/ddaeducation/DataAnalyst/blob/main/Python_Basics_101_For_Loops_%2B_Nested_For_Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # For Loops

# %%
integers = [1,2,3,4,5]

# %%
for number in integers:
    print(number)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for number in integers:
    print('yep!')
# Out:
# yep!
# yep!
# yep!
# yep!
# yep!

# %%
integers = [1,2,3,4,5]

# %%
for Jelly in integers:
    print(Jelly + Jelly)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
ice_cream_dict = {'name': 'Alex Freberg', 'weekly intake': 5, 'favorite ice creams': ['MCC', 'Chocolate']}

# %%
for cream in ice_cream_dict.values():
    print(cream)
# Out:
# Alex Freberg
# 5
# ['MCC', 'Chocolate']

# %%
for key, value in ice_cream_dict.items():
    print(key, '->',value)
# Out:
# name -> Alex Freberg
# weekly intake -> 5
# favorite ice creams -> ['MCC', 'Chocolate']

# %% [markdown]
# # Nested For Loops

# %%
flavors = ['Vanilla', 'Chocolate', 'Cookie Dough']
toppings = ['Hot Fudge', 'Oreos', 'Marshmallows']

# %%
for one in flavors:
    for two in toppings:
        print(one, 'topped with', two)
# Out:
# Vanilla topped with Hot Fudge
# Vanilla topped with Oreos
# Vanilla topped with Marshmallows
# Chocolate topped with Hot Fudge
# Chocolate topped with Oreos
# Chocolate topped with Marshmallows
# Cookie Dough topped with Hot Fudge
# Cookie Dough topped with Oreos
# Cookie Dough topped with Marshmallows

# %% [markdown]
# ![Screenshot from 2024-12-28 12-56-37.png](data:image/png;base64,...)
